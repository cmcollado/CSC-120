# %%
#Question 1
for i in range(90):
  print(i+10)

# %%
#Question 2
x = int(input("Insert a number between 0 and 99:"))
if x <= 99 and x >= 0:
  if x < 10:
    print("This is a single digit number")
  else:
    print("This is a double digit number")
else:
  print("This number in not in the specified range")

# %%
#Question 3
for i in range(10, 100):
  print(i)

# %%
#Question 4
for i in range (5, 51, 5):
  print(i)

# %%
#Question 5
for i in range (5, 51, 5):
  if i%3 == 0:
    print(str(i) + " is divisible by 3")
  else:  
    print(i)

# %%
#Question 7
prices = [10, 130, 25, 64, 91, 66, 42, 18, 141, 64]
for i in prices:
  print(i)

# %%
#Question 8
filtered_list = []
prices = [10, 130, 25, 64, 91, 66, 42, 18, 141, 64]
for i in prices:
  if i > 20 and i < 80:
    filtered_list.append(i)
print(filtered_list)

# %%
#Question 9
user = input("Username:")
pw = input("Password:")
if user == "student007" and pw == "new_password":
  print("Login successful")
else:
  print("Try again. Login failure")

# %%
#Question 10
l = len(input("Insert a username:"))
if l < 5 or l > 16:
  print("Invalid username")
else:
  print("Valid username")

# %%
#Challenge Question 1
item_prices = [10, 40, 1, 16, 25, 34, 49, 40]
for i in range(8):
  for j in range(i+1, 8):
    if item_prices[i] + item_prices[j] == 50:
      print(str(item_prices[i]) + ", " + str(item_prices[j]))

# %%
#Challenge Question 2
notFound = True
names = ["sarang","john","lily","jasmine","mara","dave","chester"]
target = input ("Enter a name:")
for i in names:
  if i == target:
    print("Name found: " + target)
    notFound = False  
if notFound:
  print("Name not found")
