# %%
#Question 6
SCORES = [40,91,85,15]
for i in range(4):
  for j in range(i+1, 4):
      print(str(SCORES[i]) + "," + str(SCORES[j]))
# Out:
# 40,91
# 40,85
# 40,15
# 91,85
# 91,15
# 85,15

# %%
#Challenge Question
s = "i_love_programming_in_python_and_i_will_alzways_program"
letters = {}
for char in s:
  letters[char] = 0
for cha in s:
  letters[cha] = letters[cha] + 1
for ch in letters:
  if letters[ch] == 1:
    print(ch)
# Out:
# v
# e
# t
# h
# d
# z
# s
